# %% [markdown]
# <a href="https://colab.research.google.com/github/leehyuno/Hard-c-language/blob/main/%ED%8C%8C%EC%9D%B4%EC%8D%AC%EB%8D%B0%EC%9D%B4%ED%84%B0%EB%B6%84%EC%84%9D_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('서울특별시 공공자전거 대여소별 이용정보(23.01~23.12).csv', encoding='cp949')
data.head()
# Out:
#    자치구                            대여소명    기준년월 대여건수 반납건수
# 0  강남구                2301. 현대고등학교 건너편  202301  383  439
# 1  강남구  2302. 교보타워 버스정류장(신논현역 3번출구 후면)  202301  433  446
# 2  강남구                 2303. 논현역 10번출구  202301  648  508
# 3  강남구                    2304. 대현그린타워  202301   76   55
# 4  강남구              2305. MCM 본사 직영점 앞  202301  172  179

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32687 entries, 0 to 32686
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   자치구     32687 non-null  object
#  1   대여소명    32687 non-null  object
#  2   기준년월    32687 non-null  int64
#  3   대여건수    32687 non-null  object
#  4   반납건수    32687 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 1.2+ MB

# %%
data.shape
# Out:
# (32687, 5)

# %%
data['대여건수'].unique()
# Out:
# array(['383', '433', '648', ..., '5191', '1981', '2669'], dtype=object)

# %%
data['반납건수'].unique()
# Out:
# array(['439', '446', '508', ..., '2635', '5181', '4226'], dtype=object)

# %%
data['대여건수'] = pd.to_numeric(data['대여건수'], errors='coerce')

# %%
data['반납건수'] = pd.to_numeric(data['반납건수'], errors='coerce')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-314bdb22dcc2> in <cell line: 0>()
# ----> 1 data['반납건수'] = pd.to_numeric(data['반납건수'], errors='coerce')
#
# NameError: name 'pd' is not defined

# %%
data.info()

# %%
data.describe()
# Out:
#                 기준년월          대여건수          반납건수
# count   32687.000000  25217.000000  25376.000000
# mean   202306.507725   1107.449776   1088.128074
# std         3.450633   1197.831526   1243.300739
# min    202301.000000      1.000000      0.000000
# 25%    202304.000000    390.000000    338.000000
# 50%    202307.000000    737.000000    702.000000
# 75%    202310.000000   1378.000000   1371.000000
# max    202312.000000  21106.000000  21201.000000

# %%
rain = pd.read_csv('강수량_및_강수일수_20250429155849.csv', encoding='cp949')
rain
# Out:
#          시점  강수량 (㎜)  강수일수 (일)
# 0   2023.01     47.9         7
# 1   2023.02      1.0         2
# 2   2023.03     10.5         3
# 3   2023.04     96.9        11
# 4   2023.05    155.6         8
# 5   2023.06    195.6        11
# 6   2023.07    459.9        19
# 7   2023.08    298.1        13
# 8   2023.09    134.5        11
# 9   2023.10     31.0         5
# 10  2023.11     81.9         7
# 11  2023.12     85.9        12

# %%
rain.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   시점        12 non-null     float64
#  1   강수량 (㎜)   12 non-null     float64
#  2   강수일수 (일)  12 non-null     int64
# dtypes: float64(2), int64(1)
# memory usage: 420.0 bytes

# %%
rain.describe()
# Out:
#                 시점     강수량 (㎜)   강수일수 (일)
# count    12.000000   12.000000  12.000000
# mean   2023.065000  133.233333   9.083333
# std       0.036056  133.062469   4.737823
# min    2023.010000    1.000000   2.000000
# 25%    2023.037500   43.675000   6.500000
# 50%    2023.065000   91.400000   9.500000
# 75%    2023.092500  165.600000  11.250000
# max    2023.120000  459.900000  19.000000
